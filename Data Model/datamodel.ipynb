# %%
# !pip install pandas

# %%
import psycopg2
import pandas as pd

# %%
try:
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=tinku")
except psycopg2.Error as e:
    print("Error: Could not make connection to the Postgres database")
    print(e)

# %%
try:
    cur = conn.cursor()
except psycopg2.error as e:
        print("Error: could not get cursor to the Database")
        print(e)

# %%
conn.set_session(autocommit=True)

# %%
try:
    cur.execute("create database accounts")
except psycopg2.Error as e:
    print(e)
# Out:
# database "accounts" already exists

# %%
try:
    conn.close()
except psycopg2.Error as e:
    print(e)
try:
    conn=psycopg2.connect("host=localhost dbname=accounts user=postgres password=tinku")
except psycopg2.Error as e:
    print("Error:could not make connection to the postgres database")
    print(e)
try:
    cur=conn.cursor()
except psycopg2.Error as e:
    print("Error:could not get curser to the Database")
    print(e)
conn.set_session(autocommit=True)

# %%
def drop_tables(cur,conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
def create_table(cur,conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit

# %%
AccountsCountry = pd.read_csv("Wealth-AccountsCountry.csv")

# %%
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
AccountsCountry_clean = AccountsCountry[['Code','Short Name','Table Name','Long Name','Currency Unit']]

# %%
AccountsCountry_clean.head()
# Out:
#   Code Short Name Table Name                  Long Name      Currency Unit
# 0  ALB    Albania    Albania        Republic of Albania       Albanian lek
# 1  ARG  Argentina  Argentina         Argentine Republic     Argentine peso
# 2  ARM    Armenia    Armenia        Republic of Armenia      Armenian dram
# 3  AUS  Australia  Australia  Commonwealth of Australia  Australian dollar
# 4  AUT    Austria    Austria        Republic of Austria               Euro

# %%
AccountsData= pd.read_csv("Wealth-AccountData.csv")

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountsSeries = pd.read_csv("Wealth-AccountSeries.csv")

# %%
AccountsSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountsSeries= AccountsSeries[['Code','Indicator Name','Long definition','Source','Topic']]

# %%
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
try:
    cur.execute("CREATE TABLE IF NOT EXISTS accounts_country (country_code varchar primary key,short_name varchar,table_name varchar,long_name varchar,currency_unit varchar);")
except psycopg2.Error as e:
    print("error: Issue creating table")
    print (e)

# %%
conn.set_session(autocommit=True)

# %%
try:
    cur.execute("CREATE TABLE IF NOT EXISTS accountsdata (country_name varchar,country_code varchar,indicator_name varchar,indicator_code varchar,year_1995 numeric,year_2000 numeric,year_2005 numeric,year_2010 numeric,year_2014 numeric);")
except psygcopg2.error as e:
    print("error:Issue creating table")
    print(e)

# %%
try:
    cur.execute("CREATE TABLE IF NOT EXISTS accountseries(series_code varchar,topic varchar,indicator_name varchar,short_defination varchar)")
except psygcopg2.error as e:
    print("error:issue creating table")
    print(e)

# %%
accounts_country_table_insert=("""insert into accountscountry(
country_code,
short_name,
table_name,
long_name,
currency_unit)
VALUES(%s,%s,%s,%s,%s)
""")

# %%
for i, row in AccountsCountry.iterrows():
    cur.execute(AccountsCountry_insert, list(row))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for i, row in AccountsCountry.iterrows():
#       2     cur.execute(AccountsCountry_insert, list(row))
#
# NameError: name 'AccountsCountry' is not defined

# %%
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 conn.commit()
#
# NameError: name 'conn' is not defined

# %%
accounts_data_table_create=("""INSERT INTO accountsdata(
country_name,
country_code,
indicator_name,
indicator_code,
year_1995,
year_2000,
year_2005,
year_2010,
year_2014)
VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
""")

# %%
for i, row in AccountsData.iterrows():
    cur.execute(accounts_country_table_insert, list(row))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 for i, row in AccountsData.iterrows():
# ----> 2     cur.execute(accounts_country_table_insert, list(row))
#
# NameError: name 'cur' is not defined

# %%
accountseries_data_table_create=("""INSERT INTO accountseries(
series_code,
topic,
indicator_name,
short_defination
)
VALUES(%S,%S,%S,%S)""")

# %%
for i, row in Accountseries.iterrows():
    cur.execute(accountseries_table_insert, list(row))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 for i, row in Accountseries.iterrows():
#       2     cur.execute(accountseries_table_insert, list(row))
#
# NameError: name 'Accountseries' is not defined

# %%
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 conn.commit()
#
# NameError: name 'conn' is not defined
